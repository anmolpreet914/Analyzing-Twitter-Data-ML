# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

# %%
#loading the dataset
df=pd.read_csv('cleaned_translation_data_1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Gender  Country  Hour  Day   Weekday  IsReshare  Reach  \
# 0           0  Unknown  Albania     7   12    Friday       True  339.0
# 1           1     Male  Albania    11    7  Thursday      False   87.0
# 2           2     Male  Albania     6   12   Tuesday      False   87.0
# 3           3     Male  Albania    10   12   Tuesday      False   87.0
# 4           4     Male  Albania     9   21  Thursday      False   85.0
#
#    RetweetCount  Likes  Klout  Sentiment Lang  \
# 0         127.0    0.0   44.0        0.0   en
# 1           0.0    0.0   22.0        0.0   en
# 2           0.0    0.0   22.0        0.0   en
# 3           0.0    0.0   22.0        0.0   en
# 4           0.0    0.0   21.0        0.0   en
#
#                                                 text  \
# 0  "RT @AdrianRusso82: Our Innovation Lab is offi...
# 1  Now Open  AWS Asia Pacific (Seoul) Region via ...
# 2  A Beginner's Guide to Scaling to 11 Million+ U...
# 3  Bridging AWS and Azure environments via VPN vi...
# 4  ELK on AWS ElasticSearch Service + ElasticBean...
#
#                                           clean_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
#
#                                      translated_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
#
#                                          valid_words
# 0  ['innovation', 'lab', 'officially', 'open', 'c...
# 1               ['open', 'pacific', 'region', 'via']
# 2             ['guide', 'scaling', 'million', 'via']
# 3                ['bridging', 'azure', 'via', 'via']
# 4                          ['elk', 'service', 'via']

# %%
# dropping columns
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Gender  Country  Hour  Day   Weekday  IsReshare  Reach  RetweetCount  \
# 0  Unknown  Albania     7   12    Friday       True  339.0         127.0
# 1     Male  Albania    11    7  Thursday      False   87.0           0.0
# 2     Male  Albania     6   12   Tuesday      False   87.0           0.0
# 3     Male  Albania    10   12   Tuesday      False   87.0           0.0
# 4     Male  Albania     9   21  Thursday      False   85.0           0.0
#
#    Likes  Klout  Sentiment Lang  \
# 0    0.0   44.0        0.0   en
# 1    0.0   22.0        0.0   en
# 2    0.0   22.0        0.0   en
# 3    0.0   22.0        0.0   en
# 4    0.0   21.0        0.0   en
#
#                                                 text  \
# 0  "RT @AdrianRusso82: Our Innovation Lab is offi...
# 1  Now Open  AWS Asia Pacific (Seoul) Region via ...
# 2  A Beginner's Guide to Scaling to 11 Million+ U...
# 3  Bridging AWS and Azure environments via VPN vi...
# 4  ELK on AWS ElasticSearch Service + ElasticBean...
#
#                                           clean_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
#
#                                      translated_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
#
#                                          valid_words
# 0  ['innovation', 'lab', 'officially', 'open', 'c...
# 1               ['open', 'pacific', 'region', 'via']
# 2             ['guide', 'scaling', 'million', 'via']
# 3                ['bridging', 'azure', 'via', 'via']
# 4                          ['elk', 'service', 'via']

# %%
df['Lang'].value_counts()
# Out:
# Lang
# en    93428
# es     1812
# fr     1097
# _u      925
# tr      899
# ja      676
# de      570
# in      427
# tl      421
# ko      365
# pt      239
# nl      174
# it      148
# zh      124
# th       81
# pl       78
# cs       74
# ru       57
# fi       51
# et       42
# ro       35
# cy       29
# ht       29
# da       28
# sv       28
# ar       22
# hu       20
# no       13
# lt        8
# lv        6
# hi        3
# iw        2
# sl        2
# uk        2
# eu        1
# km        1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (101917, 16)

# %% [markdown]
# #### At this point we are decided to drop the rows by using `Lang` column which are not translated in english as most of them are translated in it.

# %%
# List of substrings to remove
substrings_to_remove = ['_u','es', 'ht','in','it','ja','nl','pt','ro','tl','tr','zh']
# Create a regex pattern to match any of the substrings
pattern = '|'.join(substrings_to_remove)
# Remove rows where 'Lang' contains any of the substrings
df = df[~df['Lang'].str.contains(pattern)]

# %%
df.shape
# Out:
# (96008, 16)

# %%
nltk.download('stopwords')
nltk.download('punkt')

# Function to tokenize the words, remove stop words, and treat normalization
def preprocess_text(text):
    # Convert non-string inputs to strings and handle missing values
    if not isinstance(text, str):
        text = str(text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.lower() not in stop_words]

    # Normalize words by using Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    return tokens
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Apply preprocess_text function to 'clean_text' column
df['clean_text_processed'] = df['clean_text'].apply(lambda x: preprocess_text(x))

# %%
df.to_csv("cleaned_translation_data_2.csv")

# %% [markdown]
# ## Data Engineering

# %%
# dropping columns
df.drop(['Gender','Country','Hour','Day','Weekday','IsReshare','Reach','RetweetCount','Likes','Klout','Lang','text','clean_text'],axis=1,inplace=True)

# %% [markdown]
# In `Sentiment` column, the values are not well defined. So, We are dividing them into 3 categories and then applying mapping.

# %%
# The values are not well defined. So, We are dividing them into 3 categories and then applying mapping.
df['Mood'] = df['Sentiment'].apply(lambda x: 
                                       ('Positive' if x > 0 
                                             else ('Neutral' if x == 0 
                                                   else  'Negative')))

# %%
# Rename the column 'valid_words' to 'tokens'
df.rename(columns={'valid_words': 'tokens'}, inplace=True)
df[['translated_text', 'tokens', 'Sentiment','Mood']].head(10)
# Out:
#                                      translated_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
# 5  lessons years amazon web services via aresysadmin
# 6  how powerful burstable aws t instances via are...
# 7  microsoft google lead cloud growth aws rules o...
# 8  how deploy ssl certificate aws certificate man...
# 9   too bad facebook host parse a w s heroku mongo d
#
#                                               tokens  Sentiment      Mood
# 0  ['innovation', 'lab', 'officially', 'open', 'c...        0.0   Neutral
# 1               ['open', 'pacific', 'region', 'via']        0.0   Neutral
# 2             ['guide', 'scaling', 'million', 'via']        0.0   Neutral
# 3                ['bridging', 'azure', 'via', 'via']        0.0   Neutral
# 4                          ['elk', 'service', 'via']        0.0   Neutral
# 5                                     ['web', 'via']        0.0   Neutral
# 6                                ['powerful', 'via']        2.0  Positive
# 7    ['lead', 'cloud', 'growth', 'overall', 'azure']        0.0   Neutral
# 8  ['deploy', 'certificate', 'certificate', 'mana...        0.0   Neutral
# 9                      ['bad', 'host', 'parse', 'w']       -3.0  Negative

# %%
# Define a custom mapping for Mood to numerical values
mood_mapping = {
    'Neutral': 0,
    'Positive': 1,
    'Negative': 2
}

# Apply the custom mapping to create the 'Mood_Encoded' column
df['Mood'] = df['Mood'].map(mood_mapping)

# %%
df[['translated_text', 'tokens', 'Sentiment','Mood']].head(10)
# Out:
#                                      translated_text  \
# 0  our innovation lab officially open click learn...
# 1  now open aws asia pacific seoul region via are...
# 2  a beginners guide scaling million users amazon...
# 3  bridging aws azure environments via vpn via ar...
# 4  elk aws elasticsearch service elasticbeanstalk...
# 5  lessons years amazon web services via aresysadmin
# 6  how powerful burstable aws t instances via are...
# 7  microsoft google lead cloud growth aws rules o...
# 8  how deploy ssl certificate aws certificate man...
# 9   too bad facebook host parse a w s heroku mongo d
#
#                                               tokens  Sentiment  Mood
# 0  ['innovation', 'lab', 'officially', 'open', 'c...        0.0     0
# 1               ['open', 'pacific', 'region', 'via']        0.0     0
# 2             ['guide', 'scaling', 'million', 'via']        0.0     0
# 3                ['bridging', 'azure', 'via', 'via']        0.0     0
# 4                          ['elk', 'service', 'via']        0.0     0
# 5                                     ['web', 'via']        0.0     0
# 6                                ['powerful', 'via']        2.0     1
# 7    ['lead', 'cloud', 'growth', 'overall', 'azure']        0.0     0
# 8  ['deploy', 'certificate', 'certificate', 'mana...        0.0     0
# 9                      ['bad', 'host', 'parse', 'w']       -3.0     2

# %%
df.drop('Sentiment',axis=1,inplace=True)

# %%
df
# Out:
#                                           translated_text  \
# 0       our innovation lab officially open click learn...
# 1       now open aws asia pacific seoul region via are...
# 2       a beginners guide scaling million users amazon...
# 3       bridging aws azure environments via vpn via ar...
# 4       elk aws elasticsearch service elasticbeanstalk...
# ...                                                   ...
# 101912  does anyone good workflow using aws data scien...
# 101913  aws csa associate professional training availa...
# 101914  curious change opinion aws efficient dropbox r...
# 101915  new aws startup blog what startups should know...
# 101916  top paying it certifications in aws certified ...
#
#                                                    tokens  \
# 0       ['innovation', 'lab', 'officially', 'open', 'c...
# 1                    ['open', 'pacific', 'region', 'via']
# 2                  ['guide', 'scaling', 'million', 'via']
# 3                     ['bridging', 'azure', 'via', 'via']
# 4                               ['elk', 'service', 'via']
# ...                                                   ...
# 101912  ['anyone', 'good', 'data', 'science', 'spend',...
# 101913  ['associate', 'professional', 'training', 'ava...
# 101914  ['curious', 'change', 'opinion', 'efficient', ...
# 101915                        ['new', 'know', 'choosing']
# 101916        ['top', 'paying', 'certified', 'architect']
#
#                                      clean_text_processed  Mood
# 0       [innovation, lab, officially, open, click, lea...     0
# 1       [open, aws, asia, pacific, seoul, region, via,...     0
# 2       [beginner, guide, scaling, million, user, amaz...     0
# 3       [bridging, aws, azure, environment, via, vpn, ...     0
# 4       [elk, aws, elasticsearch, service, elasticbean...     0
# ...                                                   ...   ...
# 101912  [anyone, good, workflow, using, aws, data, sci...     1
# 101913  [aws, csa, associate, professional, training, ...     0
# 101914  [curious, change, opinion, aws, efficient, dro...     1
# 101915  [new, aws, startup, blog, startup, know, choos...     0
# 101916  [top, paying, certification, aws, certified, s...     0
#
# [96008 rows x 4 columns]

# %%
df.shape
# Out:
# (96008, 4)

# %%
df.to_csv("cleaned_translation_data_3.csv",index=True)
